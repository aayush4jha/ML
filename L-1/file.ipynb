# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('loan.csv')
# Out:
# /var/folders/03/sjfchj0j3d72djnp6wx7f7lh0000gn/T/ipykernel_12990/129683778.py:1: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('loan.csv')

# %%
df.shape
# Out:
# (39717, 111)

# %%
df.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%       162.87     B        B2  ...                NaN
# 1   15.27%        59.83     C        C4  ...                NaN
# 2   15.96%        84.33     C        C5  ...                NaN
# 3   13.49%       339.31     C        C1  ...                NaN
# 4   12.69%        67.79     B        B5  ...                NaN
#
#   num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75 pub_rec_bankruptcies  \
# ...

# %%
df.describe()
# Out:
#                  id     member_id     loan_amnt   funded_amnt  \
# count  3.971700e+04  3.971700e+04  39717.000000  39717.000000
# mean   6.831319e+05  8.504636e+05  11219.443815  10947.713196
# std    2.106941e+05  2.656783e+05   7456.670694   7187.238670
# min    5.473400e+04  7.069900e+04    500.000000    500.000000
# 25%    5.162210e+05  6.667800e+05   5500.000000   5400.000000
# 50%    6.656650e+05  8.508120e+05  10000.000000   9600.000000
# 75%    8.377550e+05  1.047339e+06  15000.000000  15000.000000
# max    1.077501e+06  1.314167e+06  35000.000000  35000.000000
#
#        funded_amnt_inv   installment    annual_inc           dti  \
# count     39717.000000  39717.000000  3.971700e+04  39717.000000
# mean      10397.448868    324.561922  6.896893e+04     13.315130
# std        7128.450439    208.874874  6.379377e+04      6.678594
# min           0.000000     15.690000  4.000000e+03      0.000000
# 25%        5000.000000    167.020000  4.040400e+04      8.170000
# ...

# %%
df.isnull().sum()/len(df) * 100
# Out:
# id                              0.000000
# member_id                       0.000000
# loan_amnt                       0.000000
# funded_amnt                     0.000000
# funded_amnt_inv                 0.000000
#                                  ...
# tax_liens                       0.098195
# tot_hi_cred_lim               100.000000
# total_bal_ex_mort             100.000000
# total_bc_limit                100.000000
# total_il_high_credit_limit    100.000000
# Length: 111, dtype: float64

# %%
df = df.dropna(thresh=len(df)*0.75, axis=1)

# %%
df = df.drop_duplicates()

# %%
sns.countplot(data=df, x='loan_status')
# Out:
# <Axes: xlabel='loan_status', ylabel='count'>

# %%
sns.histplot(df['loan_amnt'], kde=True)
# Out:
# <Axes: xlabel='loan_amnt', ylabel='Count'>

# %%
sns.scatterplot(data=df, x='annual_inc', y='loan_amnt', hue='loan_status')
plt.title("Annual Income vs Loan Amount")
plt.show()

# %%
sns.barplot(data=df, x='grade', y='loan_amnt', hue='loan_status')
plt.title("Average Loan Amount by Grade and Status")
plt.show()

# %%
sns.boxplot(data=df, x='loan_status', y='int_rate')
plt.title("Interest Rate Distribution by Loan Status")
plt.show()

# %%
sns.pairplot(df[['loan_amnt', 'int_rate', 'annual_inc', 'loan_status']], hue='loan_status')
plt.suptitle("Pairplot of Selected Features", y=1.02)
plt.show()

# %%
df_sorted = df.sort_values(by='annual_inc')
sns.lineplot(data=df_sorted, x='annual_inc', y='int_rate')
plt.title("Line Plot of Interest Rate vs Annual Income")
plt.xlabel("Annual Income")
plt.ylabel("Interest Rate")
# Out:
# Text(0, 0.5, 'Interest Rate')
